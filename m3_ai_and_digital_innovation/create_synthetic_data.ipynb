# %% [markdown]
# This notebook creates a synthetic data for testing customer feedback analysis.

# %%
import pandas as pd

# Generate synthetic customer feedback data for training and testing
data = {
    "text": [
        "The application crashes whenever I try to upload a file.",
        "Great user interface, but the login is slow.",
        "I found a bug in the reporting tool; it keeps timing out.",
        "Customer support is responsive, but the security dashboard is confusing.",
        "The system flagged a false positive on my security scan.",
        "I am unable to reset my password through the app.",
        "Overall, a good experience, but I wish the security settings were easier to find.",
        "The tool's threat detection feature is very accurate, but it takes too long to analyze.",
        "I experienced a data breach, and the support team didn't help much.",
        "Great tool for cybersecurity, but it lacks integration with third-party apps.",
    ],
    "priority": ["High", "Low", "Medium", "Low", "Medium", "High", "Low", "Medium", "High", "Medium"],
}

# Create a DataFrame
df = pd.DataFrame(data)

# Get current path of the notebook
from pathlib import Path

notebook_path = Path.cwd()

# Save synthetic data to CSV
train_path = notebook_path / "synthetic_train_data.csv"
test_path = notebook_path / "synthetic_test_data.csv"

# Save the data to CSV for both train and test purposes
df.to_csv(train_path, index=False)
df.to_csv(test_path, index=False)

train_path, test_path
# Out:
# (PosixPath('/home/amruthvvkp/projects/ai-playground/m3_ai_and_digital_innovation/synthetic_train_data.csv'),
#  PosixPath('/home/amruthvvkp/projects/ai-playground/m3_ai_and_digital_innovation/synthetic_test_data.csv'))
