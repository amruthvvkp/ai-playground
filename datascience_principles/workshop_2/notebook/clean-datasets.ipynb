# %% [markdown]
# # Clean Datasets and create a master copy
#
# We have 3 datasets of varying quality and completeness. We will clean them and create a master copy for further analysis.
#
# We can use Pandas to read the datasets into dataframes.

# %% [markdown]
# Read all the datasets into dataframes, clean them and create a master copy.

# %%
import pandas as pd
from pathlib import Path

def clean_datasets(raw_players_extended_file, raw_players_file, raw_squads_file):
    """
    Reads and cleans the raw datasets.

    Parameters:
    raw_players_extended_file (str): Filepath of the raw players extended dataset.
    raw_players_file (str): Filepath of the raw players dataset.
    raw_squads_file (str): Filepath of the raw squads dataset.

    Returns:
    pandas.DataFrame: Cleaned players extended dataset.
    pandas.DataFrame: Cleaned players dataset.
    pandas.DataFrame: Cleaned squads dataset.
    """

    raw_players_extended = pd.read_csv(raw_players_extended_file, encoding="utf-8", low_memory=False)
    raw_players = pd.read_excel(raw_players_file)
    raw_squads = pd.read_excel(raw_squads_file)

    return raw_players_extended, raw_players, raw_squads

raw_players_file = Path("../raw_datasets/FIFA PLAYERS.xlsx")
raw_players_extended_file = Path("../raw_datasets/FIFA PLAYERS.csv")
raw_squads_file = Path("../raw_datasets/FIFA SQUADS.xlsx")

cleaned_players_extended, cleaned_players, cleaned_squads = clean_datasets(raw_players_extended_file, raw_players_file, raw_squads_file)

# %% [markdown]
# One of the datasets has been decoded using utf-8 encoding. This has resulted in the columns under "Values" and "Wages" as currency symbols. We will clean this dataset. Ideally we want them to be integers so that it is easier to perform calculations and analysis.

# %%
def convert_currency(value):
    """
    Convert a currency value to an integer.

    Parameters:
    value (str): The currency value to be converted.

    Returns:
    int: The converted currency value as an integer.
    """
    if value == '€0':
        return 0
    elif value[-1] == 'M':
        return int(float(value[1:-1]) * 1000000)
    elif value[-1] == 'K':
        return int(float(value[1:-1]) * 1000)
    else:
        return int(value)

cleaned_players_extended['Value'] = cleaned_players_extended['Value'].apply(convert_currency)
cleaned_players_extended['Wage'] = cleaned_players_extended['Wage'].apply(convert_currency)

# %% [markdown]
# Merge cleaned datasets to create a master dataset.

# %%
master = pd.merge(cleaned_players_extended, cleaned_players, left_on=["Name","Age", "Club", "Nationality", "Overall", "Potential", "Value", "Wage"], right_on=["Name","Age", "Club", "Nationality", "Overall", "Potential", "Value", "Wage"], how="left")
master = pd.merge(master, cleaned_squads, left_on=["Name","Age", "Club"], right_on=["Player", "Age", "Club"], how="left")

# %% [markdown]
# Clean the datasets by dropping columns with all NaN values and the "Unnamed: 0" column.

# %%
master.dropna(axis=1, how='all', inplace=True)
master.drop("Unnamed: 0", axis=1, inplace=True)

# %% [markdown]
# Saves the 'master' dataframe to an Excel file named 'master.xlsx'.

# %%
master.to_excel(Path("master.xlsx").resolve(), index=False)

# %%
import plotly.graph_objects as go

# Create a scatter plot
fig = go.Figure(data=go.Scatter(x=master['Name'], y=master['Age'], mode='markers'))

# Set the title and axis labels
fig.update_layout(title='Age Distribution', xaxis_title='Name', yaxis_title='Age')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="4f9a9ec4-316c-46e3-a65c-d4c3133b46f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4
. N'Zonzi","M. Musacchio","O. Toprak","Jos\u00e9 Callej\u00f3n","Adrien Silva","S. Giovinco","N. Gait\u00e1n","M. Mand\u017euki\u0107","A. Lallana","B. H\u00f6wedes","E. Banega","Rui Patr\u00edcio","Y. Sommer","M. Schneiderlin","Jonas","K. Gameiro","L. Piszczek","E. Garay","A. Valencia","K. Schmeichel","M. Demb\u00e9l\u00e9","Borja Valero","L. Perrin","L. Biglia","Juanfran","Diego L\u00f3pez","Santi Cazorla","J. Mascherano","W. Sneijder","Nani","D. De Rossi","Jos\u00e9 Reina","Quaresma","Y. Tour\u00e9","Casillas","G. Donnarumma","L. San\u00e9","T. Bakayoko","C. Tolisso","I. Slimani","N. Fekir","J. Seri","K. Bald\u00e9 Diao","J. Tah","F. Bernardeschi","T. Werner","Andr\u00e9 Gomes","A. Martial","L. Goretzka","Q. Promes","Lucas V\u00e1zquez","Sa\u00fal","Felipe","C. Bacca","F. V\u00e1zquez","M. Kova\u010di\u0107","Sergio Rico","Manu Trigueros","A. R\u00fcdiger","F. Thauvin","S. Savi\u0107","I\u00f1igo Mart\u00ednez","Roque Mesa","A. Florenzi","D. Klaassen","K. Bellarabi","R. Sterling","Suso","Deulofeu","E. Dier","M. Rojo","Lucas","H. Son","F. Acerbi","G. Xhaka","Jonathan Viera","Pizzi","Willian Jos\u00e9","O. Baumann","G. Medel","V\u00edctor Ru\u00edz","X. Shaqiri","J. Cuadrado ...

# %%
import plotly.graph_objects as go

# Create a scatter plot
fig = go.Figure(data=go.Scatter(x=master['Age'], y=master['Nationality'], mode='markers', text=master['Flag'], marker=dict(size=10)))

# Set the title and axis labels
fig.update_layout(title='Age vs Nationality', xaxis_title='Age', yaxis_title='Nationality')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="82f70408-1393-49d5-88cd-0aba8f2d4e66" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82f70408-1393-49d5-88cd-0aba8f2d4e66")) {                    Plotly.newPlot(                        "82f70408-1393-49d5-88cd-0aba8f2d4e66",                        [{"marker":{"size":10},"mode":"markers","text":["https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f38.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f52.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f54.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f60.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f21.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f37.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f45.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f7.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f21.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f52.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f45.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f7.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f7.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f55.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f10.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f50.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f52.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f27.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f27.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f52.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f44.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f18.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f45.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f115.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f27.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f21.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f60.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f21.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f21.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f18.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f54.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f46.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f34.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f18.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f27.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f18.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f13.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f55.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f60.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f54.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f43.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f10.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f45.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f44.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f45.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f45.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f14.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f56.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f45.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f4.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f7.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f54.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f21.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f45.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f54.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f21.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f7.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f54.png","https:\u002f\u002fcdn.sofifa.org\u002fflags\u002f45.png","http ...

# %%
# import matplotlib.pyplot as plt

# # Group the data by Club and calculate the mean Overall value
# club_overall = master.groupby('Club')['Overall'].mean()

# # Create a bar plot
# plt.figure(figsize=(12, 6))
# club_overall.plot(kind='bar')
# plt.title('Overall Value by Club')
# plt.xlabel('Club')
# plt.ylabel('Overall Value')
# plt.xticks(rotation=90)
# plt.show()
